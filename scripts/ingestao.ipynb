# %%
import duckdb
import pandas as pd
import os
from datetime import datetime

# %%
df = pd.DataFrame() 

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
df = pd.read_csv('../landing/z0019_1.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df = pd.read_csv('../landing/z0019_1.csv')
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import pandas as pd

df = pd.read_csv("z0019_1.csv", sep=";")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("z0019_1.csv", sep=";")
#       4 print(df.head())
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd

df = pd.read_csv("landing/z0019_1.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("landing/z0019_1.csv", sep=";")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
import os

print("Pasta atual:", os.getcwd())
print("Arquivos:", os.listdir())
# Out:
# Pasta atual: c:\Users\Jussie\Desktop\desenvolvimento\myproject\scripts
# Arquivos: ['dados_duckdb.db', 'ingestao.ipynb']

# %%
import pandas as pd

df = pd.read_csv("landing/z0019_1.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("landing/z0019_1.csv", sep=";")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
import pandas as pd

df = pd.read_csv(r"landing\z0019_1.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv(r"landing\z0019_1.csv", sep=";")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
import os

print("Diretório atual:", os.getcwd())
print("Existe o arquivo?", os.path.exists("landing/z0019_1.csv"))
# Out:
# Diretório atual: c:\Users\Jussie\Desktop\desenvolvimento\myproject\scripts
# Existe o arquivo? False

# %%
df = pd.read_csv(r"C:\Users\Jussie\Desktop\desenvolvimento\myproject\landing\z0019_1.csv", sep=";")

# %%
import pandas as pd

df = pd.read_csv(r"landing\z0019_1.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv(r"landing\z0019_1.csv", sep=";")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
import os

print(os.getcwd())
print(os.path.exists("../landing/z0019_1.csv"))
# Out:
# c:\Users\Jussie\Desktop\desenvolvimento\myproject\scripts
# True

# %%
import pandas as pd
data_ingestao = datetime.now()
arquivo = 'z0019_2.csv'
df = pd.read_csv(f"../landing/{arquivo}", sep=";")
df['nome_arquivo'] = arquivo
df['data_ingestao'] = data_ingestao
df.head()
# Out:
#    NATBR    MAKTX WERKS  MAINS  LABST nome_arquivo              data_ingestao
# 0   1004    SERRA  BT10    100    200  z0019_2.csv 2026-07-07 22:24:49.149001
# 1   1005  MACHADO  BT10    100    200  z0019_2.csv 2026-07-07 22:24:49.149001
# 2   1003    PREGO  BT10    100     60  z0019_2.csv 2026-07-07 22:24:49.149001

# %%
print(datetime.now())
# Out:
# 2026-07-07 22:04:57.865171

# %%
con.execute("""
    CREATE TABLE IF NOT EXISTS bronze_produtos (
            NATBR VARCHAR,
            MAKTX VARCHAR,
            WERKS VARCHAR,
            MAINS VARCHAR,
            LABST VARCHAR,  
            nome_arquivo VARCHAR,
            data_ingestao TIMESTAMP
    )
""")

# %%
con.execute("INSERT INTO bronze_produtos SELECT * FROM df")

# %%
resultado = con.execute("SELECT * FROM bronze_produtos").fetchdf()
print(resultado)
# Out:
#   NATBR     MAKTX WERKS MAINS LABST nome_arquivo              data_ingestao
# 0  1001  PARAFUSO  BT10   100   100  z0019_1.csv 2026-07-07 22:10:48.295697
# 1  1002   MARTELO  BT50   100  1500  z0019_1.csv 2026-07-07 22:10:48.295697
# 2  1003     PREGO  BT10   100    50  z0019_1.csv 2026-07-07 22:10:48.295697
# 3  1004     SERRA  BT10   100   200  z0019_2.csv 2026-07-07 22:24:49.149001
# 4  1005   MACHADO  BT10   100   200  z0019_2.csv 2026-07-07 22:24:49.149001
# 5  1003     PREGO  BT10   100    60  z0019_2.csv 2026-07-07 22:24:49.149001

# %%
con.execute("ALTER TABLE bronze_produtos RENAME TO bronze_z0019")

# %%
con.close()
